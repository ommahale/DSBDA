# %%
import pandas as pd
import numpy as np

# %%
new=pd.read_csv("dirtydata.csv")

# %%
new
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127    -300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
new.isnull().sum()
# Out:
# Duration    0
# Date        1
# Pulse       0
# Maxpulse    0
# Calories    2
# dtype: int64

# %%
new.describe()
# Out:
#          Duration       Pulse    Maxpulse    Calories
# count   32.000000   32.000000   32.000000   30.000000
# mean    68.437500  103.500000  128.500000  266.013333
# std     70.039591    7.832933   12.998759  164.876415
# min     30.000000   90.000000  101.000000 -300.000000
# 25%     60.000000  100.000000  120.000000  247.000000
# 50%     60.000000  102.500000  127.500000  282.200000
# 75%     60.000000  106.500000  132.250000  343.975000
# max    450.000000  130.000000  175.000000  479.000000

# %%
a=new['Calories'].mean()

# %%
new['Calories'].fillna(a,inplace=True)  #filling NaN values in calories with their mean

# %%
new
# Out:
#     Duration          Date  Pulse  Maxpulse    Calories
# 0         60  '2020/12/01'    110       130  409.100000
# 1         60  '2020/12/02'    117       145  479.000000
# 2         60  '2020/12/03'    103       135  340.000000
# 3         45  '2020/12/04'    109       175  282.400000
# 4         45  '2020/12/05'    117       148  406.000000
# 5         60  '2020/12/06'    102       127 -300.000000
# 6         60  '2020/12/07'    110       136  374.000000
# 7        450  '2020/12/08'    104       134  253.300000
# 8         30  '2020/12/09'    109       133  195.100000
# 9         60  '2020/12/10'     98       124  269.000000
# 10        60  '2020/12/11'    103       147  329.300000
# 11        60  '2020/12/12'    100       120  250.700000
# 12        60  '2020/12/12'    100       120  250.700000
# 13        60  '2020/12/13'    106       128  345.300000
# 14        60  '2020/12/14'    104       132  379.300000
# 15        60  '2020/12/15'     98       123  275.000000
# ...

# %%
new.isnull().sum()    #to check the null values and find their count
# Out:
# Duration    0
# Date        1
# Pulse       0
# Maxpulse    0
# Calories    0
# dtype: int64

# %%
new.shape   #to check the dimension of dataset
# Out:
# (32, 5)

# %%
new.dtypes      #to check the data types of the dataset
# Out:
# Duration      int64
# Date         object
# Pulse         int64
# Maxpulse      int64
# Calories    float64
# dtype: object

# %%
new['Calories']=new['Calories'].abs()   #to convert negative to positive

# %%
new
# Out:
#     Duration          Date  Pulse  Maxpulse    Calories
# 0         60  '2020/12/01'    110       130  409.100000
# 1         60  '2020/12/02'    117       145  479.000000
# 2         60  '2020/12/03'    103       135  340.000000
# 3         45  '2020/12/04'    109       175  282.400000
# 4         45  '2020/12/05'    117       148  406.000000
# 5         60  '2020/12/06'    102       127  300.000000
# 6         60  '2020/12/07'    110       136  374.000000
# 7        450  '2020/12/08'    104       134  253.300000
# 8         30  '2020/12/09'    109       133  195.100000
# 9         60  '2020/12/10'     98       124  269.000000
# 10        60  '2020/12/11'    103       147  329.300000
# 11        60  '2020/12/12'    100       120  250.700000
# 12        60  '2020/12/12'    100       120  250.700000
# 13        60  '2020/12/13'    106       128  345.300000
# 14        60  '2020/12/14'    104       132  379.300000
# 15        60  '2020/12/15'     98       123  275.000000
# ...

# %%
new.round(2)
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130    409.10
# 1         60  '2020/12/02'    117       145    479.00
# 2         60  '2020/12/03'    103       135    340.00
# 3         45  '2020/12/04'    109       175    282.40
# 4         45  '2020/12/05'    117       148    406.00
# 5         60  '2020/12/06'    102       127    300.00
# 6         60  '2020/12/07'    110       136    374.00
# 7        450  '2020/12/08'    104       134    253.30
# 8         30  '2020/12/09'    109       133    195.10
# 9         60  '2020/12/10'     98       124    269.00
# 10        60  '2020/12/11'    103       147    329.30
# 11        60  '2020/12/12'    100       120    250.70
# 12        60  '2020/12/12'    100       120    250.70
# 13        60  '2020/12/13'    106       128    345.30
# 14        60  '2020/12/14'    104       132    379.30
# 15        60  '2020/12/15'     98       123    275.00
# ...

# %%
new1=new      #to make copy of main dataset

# %%
new1['Calories']=new1['Calories'].astype(int)   #convert float to int

# %%
new1.dtypes
# Out:
# Duration     int64
# Date        object
# Pulse        int64
# Maxpulse     int64
# Calories     int64
# dtype: object

# %%
new1
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130       409
# 1         60  '2020/12/02'    117       145       479
# 2         60  '2020/12/03'    103       135       340
# 3         45  '2020/12/04'    109       175       282
# 4         45  '2020/12/05'    117       148       406
# 5         60  '2020/12/06'    102       127       300
# 6         60  '2020/12/07'    110       136       374
# 7        450  '2020/12/08'    104       134       253
# 8         30  '2020/12/09'    109       133       195
# 9         60  '2020/12/10'     98       124       269
# 10        60  '2020/12/11'    103       147       329
# 11        60  '2020/12/12'    100       120       250
# 12        60  '2020/12/12'    100       120       250
# 13        60  '2020/12/13'    106       128       345
# 14        60  '2020/12/14'    104       132       379
# 15        60  '2020/12/15'     98       123       275
# ...

# %%
new.dropna()
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130       409
# 1         60  '2020/12/02'    117       145       479
# 2         60  '2020/12/03'    103       135       340
# 3         45  '2020/12/04'    109       175       282
# 4         45  '2020/12/05'    117       148       406
# 5         60  '2020/12/06'    102       127       300
# 6         60  '2020/12/07'    110       136       374
# 7        450  '2020/12/08'    104       134       253
# 8         30  '2020/12/09'    109       133       195
# 9         60  '2020/12/10'     98       124       269
# 10        60  '2020/12/11'    103       147       329
# 11        60  '2020/12/12'    100       120       250
# 12        60  '2020/12/12'    100       120       250
# 13        60  '2020/12/13'    106       128       345
# 14        60  '2020/12/14'    104       132       379
# 15        60  '2020/12/15'     98       123       275
# ...

# %%
new['Date']=pd.to_datetime(new['Date'])

# %%
new
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130       409
# 1         60 2020-12-02    117       145       479
# 2         60 2020-12-03    103       135       340
# 3         45 2020-12-04    109       175       282
# 4         45 2020-12-05    117       148       406
# 5         60 2020-12-06    102       127       300
# 6         60 2020-12-07    110       136       374
# 7        450 2020-12-08    104       134       253
# 8         30 2020-12-09    109       133       195
# 9         60 2020-12-10     98       124       269
# 10        60 2020-12-11    103       147       329
# 11        60 2020-12-12    100       120       250
# 12        60 2020-12-12    100       120       250
# 13        60 2020-12-13    106       128       345
# 14        60 2020-12-14    104       132       379
# 15        60 2020-12-15     98       123       275
# 16        60 2020-12-16     98       120       215
# ...

# %%
new.dropna()
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130       409
# 1         60 2020-12-02    117       145       479
# 2         60 2020-12-03    103       135       340
# 3         45 2020-12-04    109       175       282
# 4         45 2020-12-05    117       148       406
# 5         60 2020-12-06    102       127       300
# 6         60 2020-12-07    110       136       374
# 7        450 2020-12-08    104       134       253
# 8         30 2020-12-09    109       133       195
# 9         60 2020-12-10     98       124       269
# 10        60 2020-12-11    103       147       329
# 11        60 2020-12-12    100       120       250
# 12        60 2020-12-12    100       120       250
# 13        60 2020-12-13    106       128       345
# 14        60 2020-12-14    104       132       379
# 15        60 2020-12-15     98       123       275
# 16        60 2020-12-16     98       120       215
# ...

# %%
new.loc[7,'Duration']=45

# %%
new
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130       409
# 1         60 2020-12-02    117       145       479
# 2         60 2020-12-03    103       135       340
# 3         45 2020-12-04    109       175       282
# 4         45 2020-12-05    117       148       406
# 5         60 2020-12-06    102       127       300
# 6         60 2020-12-07    110       136       374
# 7         45 2020-12-08    104       134       253
# 8         30 2020-12-09    109       133       195
# 9         60 2020-12-10     98       124       269
# 10        60 2020-12-11    103       147       329
# 11        60 2020-12-12    100       120       250
# 12        60 2020-12-12    100       120       250
# 13        60 2020-12-13    106       128       345
# 14        60 2020-12-14    104       132       379
# 15        60 2020-12-15     98       123       275
# 16        60 2020-12-16     98       120       215
# ...

# %%
new.dropna()
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130       409
# 1         60 2020-12-02    117       145       479
# 2         60 2020-12-03    103       135       340
# 3         45 2020-12-04    109       175       282
# 4         45 2020-12-05    117       148       406
# 5         60 2020-12-06    102       127       300
# 6         60 2020-12-07    110       136       374
# 7         45 2020-12-08    104       134       253
# 8         30 2020-12-09    109       133       195
# 9         60 2020-12-10     98       124       269
# 10        60 2020-12-11    103       147       329
# 11        60 2020-12-12    100       120       250
# 12        60 2020-12-12    100       120       250
# 13        60 2020-12-13    106       128       345
# 14        60 2020-12-14    104       132       379
# 15        60 2020-12-15     98       123       275
# 16        60 2020-12-16     98       120       215
# ...

# %%
new.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12     True
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# dtype: bool

# %%
new.duplicated().sum()
# Out:
# 1

# %%
new.drop_duplicates(inplace=True)

# %%
new
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130       409
# 1         60 2020-12-02    117       145       479
# 2         60 2020-12-03    103       135       340
# 3         45 2020-12-04    109       175       282
# 4         45 2020-12-05    117       148       406
# 5         60 2020-12-06    102       127       300
# 6         60 2020-12-07    110       136       374
# 7         45 2020-12-08    104       134       253
# 8         30 2020-12-09    109       133       195
# 9         60 2020-12-10     98       124       269
# 10        60 2020-12-11    103       147       329
# 11        60 2020-12-12    100       120       250
# 13        60 2020-12-13    106       128       345
# 14        60 2020-12-14    104       132       379
# 15        60 2020-12-15     98       123       275
# 16        60 2020-12-16     98       120       215
# 17        60 2020-12-17    100       120       300
# ...

# %%
new.duplicated().sum()
# Out:
# 0

# %%
#new dataset

# %%
df=pd.read_csv('nba.csv')

# %%
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25   2-Jun     180
# 1      Jae Crowder  Boston Celtics      99       SF   25   6-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27   5-Jun     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22   5-Jun     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  10-Jun     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 452     Trey Lyles       Utah Jazz      41       PF   20  10-Jun     234
# 453   Shelvin Mack       Utah Jazz       8       PG   26   3-Jun     203
# 454      Raul Neto       Utah Jazz      25       PG   24   1-Jun     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26   3-Jul     256
# 456    Jeff Withey       Utah Jazz      24        C   26  Jul-00     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df.shape
# Out:
# (457, 9)

# %%
df.dtypes
# Out:
# Name         object
# Team         object
# Number        int64
# Position     object
# Age           int64
# Height       object
# Weight        int64
# College      object
# Salary      float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Name         0
# Team         0
# Number       0
# Position     0
# Age          0
# Height       0
# Weight       0
# College     84
# Salary      11
# dtype: int64

# %%
df['Position'].unique()
# Out:
# array(['PG', 'SF', 'SG', 'PF', 'C'], dtype=object)

# %%
df['Position'].value_counts()
# Out:
# SG    102
# PF    100
# PG     92
# SF     85
# C      78
# Name: Position, dtype: int64

# %%
df['Pos']=df['Position'].replace(['SG','PF','PG','SF','C'],[1,2,3,4,5])  #categorical to quantative

# %%
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25   2-Jun     180
# 1      Jae Crowder  Boston Celtics      99       SF   25   6-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27   5-Jun     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22   5-Jun     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  10-Jun     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 452     Trey Lyles       Utah Jazz      41       PF   20  10-Jun     234
# 453   Shelvin Mack       Utah Jazz       8       PG   26   3-Jun     203
# 454      Raul Neto       Utah Jazz      25       PG   24   1-Jun     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26   3-Jul     256
# 456    Jeff Withey       Utah Jazz      24        C   26  Jul-00     231
#
#                College     Salary  Pos
# 0                Texas  7730337.0    3
# ...

# %%
#using label encoding

# %%
from sklearn import preprocessing

# %%
le=preprocessing.LabelEncoder()

# %%
df['Position']=le.fit_transform(df['Position'])

# %%
df
# Out:
#               Name            Team  Number  Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0         2   25   2-Jun     180
# 1      Jae Crowder  Boston Celtics      99         3   25   6-Jun     235
# 2     John Holland  Boston Celtics      30         4   27   5-Jun     205
# 3      R.J. Hunter  Boston Celtics      28         4   22   5-Jun     185
# 4    Jonas Jerebko  Boston Celtics       8         1   29  10-Jun     231
# ..             ...             ...     ...       ...  ...     ...     ...
# 452     Trey Lyles       Utah Jazz      41         1   20  10-Jun     234
# 453   Shelvin Mack       Utah Jazz       8         2   26   3-Jun     203
# 454      Raul Neto       Utah Jazz      25         2   24   1-Jun     179
# 455   Tibor Pleiss       Utah Jazz      21         0   26   3-Jul     256
# 456    Jeff Withey       Utah Jazz      24         0   26  Jul-00     231
#
#                College     Salary  Pos
# 0                Texas  7730337.0    3
# ...

# %%
#qunatative to category

# %%
cat=pd.cut(df.Age,bins=[19,25,30,35,45],labels=['A','B','C','D'])

# %%
df.insert(5,'Age_Grp',cat)

# %%
df
# Out:
#               Name            Team  Number  Position  Age Age_Grp  Height  \
# 0    Avery Bradley  Boston Celtics       0         2   25       A   2-Jun
# 1      Jae Crowder  Boston Celtics      99         3   25       A   6-Jun
# 2     John Holland  Boston Celtics      30         4   27       B   5-Jun
# 3      R.J. Hunter  Boston Celtics      28         4   22       A   5-Jun
# 4    Jonas Jerebko  Boston Celtics       8         1   29       B  10-Jun
# ..             ...             ...     ...       ...  ...     ...     ...
# 452     Trey Lyles       Utah Jazz      41         1   20       A  10-Jun
# 453   Shelvin Mack       Utah Jazz       8         2   26       B   3-Jun
# 454      Raul Neto       Utah Jazz      25         2   24       A   1-Jun
# 455   Tibor Pleiss       Utah Jazz      21         0   26       B   3-Jul
# 456    Jeff Withey       Utah Jazz      24         0   26       B  Jul-00
#
#      Weight            College     Salary  Pos
# ...

# %%
df.to_csv('nba_preprocessed.csv')

# %%
#new dataset

# %%
df1=pd.read_csv('A1_ALCHOHOL.csv')

# %%
df1
# Out:
#            Country   Alcohol   Deaths   Heart      Liver
# 0        Australia       2.50      785  211.0  15.300000
# 1          Austria       3.00      863  167.0  45.599998
# 2   Belg. and Lux.       2.90      883  131.0  20.700001
# 3           Canada       2.40      793    NaN  16.400000
# 4          Denmark       2.90      971  220.0  23.900000
# 5          Finland       0.80      970  297.0  19.000000
# 6           France       9.10      751   11.0  37.900002
# 7          Iceland      -0.80      743  211.0  11.200000
# 8          Ireland       0.70     1000  300.0   6.500000
# 9           Israel       0.60     -834  183.0  13.700000
# 10           Italy      27.90      775  107.0  42.200001
# 11           Japan       1.50      680   36.0  23.200001
# 12     Netherlands       1.80      773  167.0   9.200000
# 13     New Zealand       1.90      916  266.0   7.700000
# 14          Norway       0.08      806  227.0  12.200000
# ...

# %%
df1.columns
# Out:
# Index(['Country', ' Alcohol ', 'Deaths ', 'Heart', ' Liver'], dtype='object')

# %%
df1.columns=[c.strip() for c in df1.columns]

# %%
df1
# Out:
#            Country  Alcohol  Deaths  Heart      Liver
# 0        Australia     2.50     785  211.0  15.300000
# 1          Austria     3.00     863  167.0  45.599998
# 2   Belg. and Lux.     2.90     883  131.0  20.700001
# 3           Canada     2.40     793    NaN  16.400000
# 4          Denmark     2.90     971  220.0  23.900000
# 5          Finland     0.80     970  297.0  19.000000
# 6           France     9.10     751   11.0  37.900002
# 7          Iceland    -0.80     743  211.0  11.200000
# 8          Ireland     0.70    1000  300.0   6.500000
# 9           Israel     0.60    -834  183.0  13.700000
# 10           Italy    27.90     775  107.0  42.200001
# 11           Japan     1.50     680   36.0  23.200001
# 12     Netherlands     1.80     773  167.0   9.200000
# 13     New Zealand     1.90     916  266.0   7.700000
# 14          Norway     0.08     806  227.0  12.200000
# 15           Spain     6.50     724    NaN        NaN
# ...

# %%
df1.columns
# Out:
# Index(['Country', 'Alcohol', 'Deaths', 'Heart', 'Liver'], dtype='object')

# %%
df1.shape
# Out:
# (22, 5)

# %%
df1.dtypes
# Out:
# Country     object
# Alcohol    float64
# Deaths       int64
# Heart      float64
# Liver      float64
# dtype: object

# %%
df1.describe()
# Out:
#          Alcohol       Deaths       Heart      Liver
# count  22.000000    22.000000   20.000000  21.000000
# mean    3.605909   750.590909  184.150000  20.265238
# std     5.862724   366.636535   77.707464  11.428617
# min    -0.800000  -834.000000   11.000000   6.500000
# 25%     1.225000   744.750000  158.000000  11.200000
# 50%     2.150000   789.000000  191.000000  19.000000
# 75%     2.937500   907.750000  221.750000  23.200001
# max    27.900000  1000.000000  300.000000  45.599998

# %%
df1.isnull().sum()
# Out:
# Country    0
# Alcohol    0
# Deaths     0
# Heart      2
# Liver      1
# dtype: int64

# %%
b=df1['Heart'].mean()

# %%
b
# Out:
# 184.15

# %%
df1['Deaths']=df1['Deaths'].abs()

# %%
df1
# Out:
#            Country  Alcohol  Deaths  Heart      Liver
# 0        Australia     2.50     785  211.0  15.300000
# 1          Austria     3.00     863  167.0  45.599998
# 2   Belg. and Lux.     2.90     883  131.0  20.700001
# 3           Canada     2.40     793    NaN  16.400000
# 4          Denmark     2.90     971  220.0  23.900000
# 5          Finland     0.80     970  297.0  19.000000
# 6           France     9.10     751   11.0  37.900002
# 7          Iceland    -0.80     743  211.0  11.200000
# 8          Ireland     0.70    1000  300.0   6.500000
# 9           Israel     0.60     834  183.0  13.700000
# 10           Italy    27.90     775  107.0  42.200001
# 11           Japan     1.50     680   36.0  23.200001
# 12     Netherlands     1.80     773  167.0   9.200000
# 13     New Zealand     1.90     916  266.0   7.700000
# 14          Norway     0.08     806  227.0  12.200000
# 15           Spain     6.50     724    NaN        NaN
# ...

# %%
df1['Alcohol']=df1['Alcohol'].abs()

# %%
df1
# Out:
#            Country  Alcohol  Deaths  Heart      Liver
# 0        Australia     2.50     785  211.0  15.300000
# 1          Austria     3.00     863  167.0  45.599998
# 2   Belg. and Lux.     2.90     883  131.0  20.700001
# 3           Canada     2.40     793    NaN  16.400000
# 4          Denmark     2.90     971  220.0  23.900000
# 5          Finland     0.80     970  297.0  19.000000
# 6           France     9.10     751   11.0  37.900002
# 7          Iceland     0.80     743  211.0  11.200000
# 8          Ireland     0.70    1000  300.0   6.500000
# 9           Israel     0.60     834  183.0  13.700000
# 10           Italy    27.90     775  107.0  42.200001
# 11           Japan     1.50     680   36.0  23.200001
# 12     Netherlands     1.80     773  167.0   9.200000
# 13     New Zealand     1.90     916  266.0   7.700000
# 14          Norway     0.08     806  227.0  12.200000
# 15           Spain     6.50     724    NaN        NaN
# ...

# %%
df1.loc[10,'Alcohol']=7.90

# %%
df1
# Out:
#            Country  Alcohol  Deaths  Heart      Liver
# 0        Australia     2.50     785  211.0  15.300000
# 1          Austria     3.00     863  167.0  45.599998
# 2   Belg. and Lux.     2.90     883  131.0  20.700001
# 3           Canada     2.40     793    NaN  16.400000
# 4          Denmark     2.90     971  220.0  23.900000
# 5          Finland     0.80     970  297.0  19.000000
# 6           France     9.10     751   11.0  37.900002
# 7          Iceland     0.80     743  211.0  11.200000
# 8          Ireland     0.70    1000  300.0   6.500000
# 9           Israel     0.60     834  183.0  13.700000
# 10           Italy     7.90     775  107.0  42.200001
# 11           Japan     1.50     680   36.0  23.200001
# 12     Netherlands     1.80     773  167.0   9.200000
# 13     New Zealand     1.90     916  266.0   7.700000
# 14          Norway     0.08     806  227.0  12.200000
# 15           Spain     6.50     724    NaN        NaN
# ...

# %%
df1.describe()
# Out:
#          Alcohol       Deaths       Heart      Liver
# count  22.000000    22.000000   20.000000  21.000000
# mean    2.769545   826.409091  184.150000  20.265238
# std     2.421240    95.726127   77.707464  11.428617
# min     0.080000   680.000000   11.000000   6.500000
# 25%     1.225000   750.250000  158.000000  11.200000
# 50%     2.150000   799.500000  191.000000  19.000000
# 75%     2.937500   907.750000  221.750000  23.200001
# max     9.100000  1000.000000  300.000000  45.599998

# %%
c=df1['Liver'].mean()

# %%
c
# Out:
# 20.265238149428573

# %%
df1['Liver'].fillna(c,inplace=True)

# %%
df1
# Out:
#            Country  Alcohol  Deaths  Heart      Liver
# 0        Australia     2.50     785  211.0  15.300000
# 1          Austria     3.00     863  167.0  45.599998
# 2   Belg. and Lux.     2.90     883  131.0  20.700001
# 3           Canada     2.40     793    NaN  16.400000
# 4          Denmark     2.90     971  220.0  23.900000
# 5          Finland     0.80     970  297.0  19.000000
# 6           France     9.10     751   11.0  37.900002
# 7          Iceland     0.80     743  211.0  11.200000
# 8          Ireland     0.70    1000  300.0   6.500000
# 9           Israel     0.60     834  183.0  13.700000
# 10           Italy     7.90     775  107.0  42.200001
# 11           Japan     1.50     680   36.0  23.200001
# 12     Netherlands     1.80     773  167.0   9.200000
# 13     New Zealand     1.90     916  266.0   7.700000
# 14          Norway     0.08     806  227.0  12.200000
# 15           Spain     6.50     724    NaN  20.265238
# ...
